# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('y-label')
plt.show()

# %%
# x, y값 그래프로 지정 가능
plt.plot([1,2,3,4], [1, 4, 9, 16])

# %%
plt.plot([1,2,3,4], [1, 4, 9, 16], 'ro') #ro = rew 'o'

#plt.asix([xmin, xmax, ymin, ymax])
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ### 여러 개의 그래프 그리기

# %%
t = np.arange(0., 5.,0.2)

# 빨간 대시, 파란 삼각형, 노랑색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## 02. 축 레이블 설정

# %%
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.xlabel('X-Label')
plt.ylabel('y-Label')
plt.show()

# %% [markdown]
# ## 축 범위 설정하기

# %%
plt.plot([1,2,3,4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('y-Babel')
plt.axis([0, 5, 0, 20])
plt.show()

# %% [markdown]
# ##  Marker 지정하기

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bo')
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.axis([0, 5, 0, 20])
plt.show()

# %% [markdown]
# ##  색상 지정하기

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], color = 'springgreen')
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.axis([0, 5, 0, 20])
plt.show()

# %% [markdown]
# ###  선, 마커, 색상 지정하기

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], color = '#e35f62', marker  ='o',
        linestyle='--')
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.axis([0, 5, 0, 20])
plt.show()

# %% [markdown]
# ## 그래프 영역채우기
#
#     - fill_between()
#     - fill_betweenx()
#     - fill()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.fill_between(x[1:3], y[1:3], alpha=0.5)  #fill_between()

plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.fill_betweenx(y[2:4], x[2:4], color = 'coral', alpha=0.5)  #fill_between()

plt.show()

# %% [markdown]
# ### 두 그래프 사이 영역채우기

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')

plt.fill_between(x[1:3], y1[1:3], y2[1:3], color = 'lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# ###  임의의 영역 채우기

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')

plt.fill([1.9, 1.9, 3.1, 3.1], [2, 5, 11, 8], color = 'lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# ## 여러 곡선 그리기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'r--', a, a**2, 'bo', a, a**3, 'g-.')
plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker = '*', linewidth=2)
plt.plot(a, a**3, color = 'green', marker = '^', markersize = 9)
plt.show()

# %% [markdown]
# ### 그리드 설정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker='^', markersize=9)

plt.grid(True)

plt.show()

# %%
# axis = y --> 가로 방향의 그리드만 표시
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker='^', markersize=9)

plt.grid(True, axis = 'y')

plt.show()

# %%
# axis = x --> 가로 방향의 그리드만 표시
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker='^', markersize=9)

plt.grid(True, axis = 'x')

plt.show()

# %%
# 라인 스타일 지정
# alpha -> 투명도
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker='^', markersize=9)

plt.grid(True, axis = 'y', color = 'red', alpha = 0.1, linestyle = '--')

plt.show()

# %% [markdown]
# ## 눈금 표시하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker = '*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker = '^', markersize = 9)

plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# ### 눈금 레이블 지정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker = '*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker = '^', markersize = 9)

plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %% [markdown]
# ### 눈금 스타일 설정하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color = '#e35f62', marker = '*', linewidth=2)
plt.plot(a, a**3, color = 'springgreen', marker = '^', markersize = 9)

plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.tick_params(axis = 'x', direction = 'in', length = 3, pad = 6, labelsize =14,
               labelcolor = 'green')
plt.tick_params(axis = 'y', direction = 'inout', length = 10, pad = 15,
               labelsize =12, width = 2, color = 'r')
plt.show()

# %% [markdown]
# ##  타이틀 설정하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo');
plt.plot(a, a**2, color = '#e35f62', marker = '*', linewidth = 2)
plt.plot(a, a**3, color = 'pink', marker = '^', markersize = 9)

plt.grid(True, axis='y', color = 'gray', alpha = 0.5, linestyle='--')
plt.tick_params(axis='both', direction = 'in', length = 3, pad = 6,
               labelsize = 14)

# 그래프 타이틀 설정하기
plt.title("Sample garph")
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo');
plt.plot(a, a**2, color = '#e35f62', marker = '*', linewidth = 2)
plt.plot(a, a**3, color = 'pink', marker = '^', markersize = 9)

plt.grid(True, axis='y', color = 'gray', alpha = 0.5, linestyle='--')
plt.tick_params(axis='both', direction = 'in', length = 3, pad = 6,
               labelsize = 14)

# 그래프 타이틀 설정하기
plt.title("Sample garph", loc = 'right', pad =20)
plt.show()

# %% [markdown]
# ### 수직선 / 수평선 표시하기
# - axhline()
# - axvline()
# - hlines()
# - vlines()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color ='#e35f62', marker = '*', linewidth = 2)
plt.plot(a, a**3, color ='springgreen', marker = '^', markersize = 9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.axhline(1, 0, 0.55, color = 'gray', linestyle='--', linewidth = '1')
plt.axvline(1, 0, 0.16, color = 'lightgray', linestyle=':', linewidth = '2')

plt.axhline(5.83, 0, 0.95, color = 'gray', linestyle='--', linewidth='1')
plt.axvline(1.8, 0, 0.95, color = 'lightgray', linestyle=':', linewidth='2')

plt.show()

# %% [markdown]
# ### hlines/vlines

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color ='#e35f62', marker = '*', linewidth = 2)
plt.plot(a, a**3, color ='springgreen', marker = '^', markersize = 9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.hlines(4, 1, 1.6, colors='pink', linewidth = 3)
# x.min, x.max를 순서대로 입력하면, 점 (xmin, y), (xmax, y)을 따라 수평선을 표시합니다.

plt.vlines(1, 1, 4, colors='pink', linewidth = 3)
# x, ymin, ymax를 순서대로 입력하면, 점 (x, ymin)에서 점(x, ymax)를 따라 수평선을 표시합니다.

plt.show()

# %% [markdown]
# ## 막대 그래프 그리기

# %%
x = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

# 막대그래프 -> bar
plt.bar(x, values)
plt.xticks(x, years)
plt.show()

# %% [markdown]
# ### 스타일 꾸미기

# %%
x = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

plt.bar(x, values, width = 0.6, align='edge', color = 'coral',
       edgecolor = 'gray', linewidth = 3, tick_label = years, log = True)
plt.show()

# %% [markdown]
# ## 수평 막대 그리기

# %%
y = np.arange(3)

years = ['2017', '2018', '2019']
values  = [100, 400, 900]

plt.barh(y, values, height = -0.6, align='edge', color = 'orange',
        edgecolor = 'springgreen', linewidth = 3, tick_label = years,
        log = False)
# log=False로 설정하면, x 축이 선형 스케일로 표시됩니다. 디폴트는 False입니다.
plt.show()

# %% [markdown]
# ## 산점도 그리기

# %%
np.random.seed(121434)
# np.random.seed()를 이용해서 난수 생성의ㅣ 시드를 설정하면, 같은 난수를 재사용할 수 있다.

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha = 0.5)
# alpha -> 마커 색의 투명도
plt.show()

# %% [markdown]
# ## 3차원 산점도 그리기

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
n = 100
xmin, xmax, ymin, ymax, zmin, zmax = 0, 20, 0, 20, 0, 50
cmin, cmax = 0, 2

xs = np.array([(xmax - xmin) * np.random.random_sample() + xmin for i in range(n)])
ys = np.array([(ymax - ymin) * np.random.random_sample() + ymin for i in range(n)])
zs = np.array([(zmax - xmin) * np.random.random_sample() + zmin for i in range(n)])

color = np.array([(cmax - cmin) * np.random.random_sample() + cmin for i in range(n)])

plt.rcParams['figure.figsize'] = (6, 6)
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(xs, ys, zs, c=color, marker = 'o', s=15, cmap='Greens')
plt.show()

# %% [markdown]
# ## 히스토그램 그리기

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71, 80, 59, 67,
          81, 69, 73, 69, 74, 70, 65]

plt.hist(weight)
plt.show()

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

plt.hist(a, bins = 100, density = True, alpha = 0.7, histtype = 'step')
plt.hist(b, bins = 50, density = True, alpha = 0.5, histtype = 'stepfilled')
plt.hist(c, bins = 100, density = True, alpha = 0.9, histtype = 'step')
plt.show()

# %% [markdown]
# ## 에러바 만들기

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
yerr = [2.3, 3.1, 1.7, 2.5]

# errorbar() 함수에 x, y 값들과 함께 데이터의 편차를 나타내는 리스트인 yerr을 입력합니다.
#yerr의 각 값들은 데이터 포인트의 위/아래 대칭인 오차로 표시됩니다.

plt.errorbar(x, y, yerr=yerr)
plt.show()

# %% [markdown]
# ### 비대칭 편차 나타내기

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
yerr = [(2.3, 3.1, 1.7, 2.5), (1.1, 2.5, 0.9, 3.9)]

plt.errorbar(x, y, yerr=yerr)
plt.show()

# %% [markdown]
# ### 상한 / 하한 기호 표시하기

# %%
x = np.arange(1, 5)
y = x **2
yerr = np.linspace(0.1, 0.4, 4)

plt.errorbar(x, y + 4, yerr = yerr)
plt.errorbar(x, y + 2, yerr = yerr, uplims = True, lolims=True)

upperlimits = [True, False, True, False]
lowerlimits = [False, False, True, True]

plt.errorbar(x, y, yerr=yerr, uplims = upperlimits, lolims = lowerlimits)
plt.show()

# %% [markdown]
# ## 파이 차트 그리기

# %%
# 파이 차트 (Pie chart, 원 그래프)는 범주별 구성 비율을 원형으로 표현한 그래프입니다.
# 위의 그림과 같이 부채꼴의 중심각을 구성 비율에 비례하도록 표현합니다.

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels = labels, autopct = '%.1f%%')
plt.show()

# %% [markdown]
# ### 시작 각도와 방향 설정하기

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels = labels, autopct = '%.1f%%', startangle = 260, counterclock = False)
plt.show()

# startangle는 부채꼴이 그려지는 시작 각도를 설정합니다.
# 디폴트는 0도 (양의 방향 x축)로 설정되어 있습니다.
# counterclock=False로 설정하면 시계 방향 순서로 부채꼴 영역이 표시됩니다.

# %% [markdown]
# ### 중심에서 벗어나는 정도 설정하기

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10]

plt.pie(ratio, labels = labels, autopct = '%.1f%%',
        startangle = 260, counterclock = False, explode = explode)

# explode는 부채꼴이 파이 차트의 중심에서 벗어나는 정도를 설정합니다.
# ‘Banana’와 ‘Grapes’ 영역에 대해서 반지름의 10% 만큼 벗어나도록 설정했습니다.

plt.show()

# %% [markdown]
# ### 그림자 나타내기

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]

plt.pie(ratio, labels = labels, autopct = '%.1f%%',
        startangle = 260, counterclock = False,
        explode = explode, shadow = True)
plt.show()

# %% [markdown]
# ###  색상 지정하기

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels = labels, autopct = '%.1f%%',
        startangle = 260, counterclock = False,
        explode = explode, shadow = True, colors = colors)
plt.show()

# %% [markdown]
# ### 부채꼴 스타일 지정하기

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# wedgeprops는 부채꼴 영역의 스타일을 설정합니다.
# wedgeprops 딕셔너리의 ‘width’, ‘edgecolor’, ‘linewidth’ 키를 이용해서 각각 부채꼴 영역의 너비 (반지름에 대한 비율),
